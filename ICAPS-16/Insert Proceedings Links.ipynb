# %%
# For generating the string (worth copying into an editor first to make sure all links are there -- search for '…')
# foo = ''; $('.bibbase_paper_title a').each(function(i,o) { foo += '\''+o.innerText+'\': '+'\''+o.href+'\',\n';}); console.log(foo)

FILE = '../dc.html'


dc = """<Automated Planning and Scheduling E0 Constellations' Operations using Ant Colony Optimization><Evridiki Ntagiou><abstracts/ntagiou.pdf>
<Solver Paramter Tuning and Runtime Predictions of Flexible Hybrid Mathematical models><Michael Barry><abstracts/barry.pdf>
<Constructing Heuristics for PDDL+ Planning Domains><Wiktor Piotrowski><abstracts/piotrowski.pdf>
<Risk-Sensitive Planning with Dynamic Uncertainty><Liana Marinescu><abstracts/marinescu.pdf>
<A Distributed Online Multi-Agent Planning System><Rafael Cardoso><abstracts/cardoso.pdf>
<Integrating Planning and Recognition to Close the Interaction Loop><Rick Freedman><abstracts/freedman.pdf>
<Distributed Privacy-preserving Multi-agent Planning><Andrea Bonisoli><abstracts/bonisoli.pdf>
<Planning with Concurrent Execution><Bence Cserna><abstracts/cserna.pdf>
<Mixed Discrete-Continuous Planning with Complex Behaviors><Enrique Fernandez Golzalez><abstracts/gonzalez.pdf>
<Planning with Flexible Timelines in the Real World><Alessandro Umbrico><abstracts/umbrico.pdf>
<POPCorn: Planning with Constrained Real Numerics><Emre Savas><abstracts/savas.pdf>
<Planning with PDDL3.0 Preferences by Compilation into STRIPS with Action Costs><Francesco Percassi><abstracts/percassi.pdf>
<Planning Under Uncertainty with Temporally Extended Goals><Alberto Camacho><abstracts/camacho.pdf>
<Temporal Inference In Forward Search Temporal Planning><Atif Talukdar><abstracts/talukdar.pdf>
<Task Scheduling and Trajectory Generation of Multiple Intelligent Vehicles><Jennifer David><abstracts/david.pdf>
<Decoupled State Space Search><Daniel Gnad><abstracts/gnad.pdf> 
<Hierarchical Task Model with Alternatives for Predictive-reactive Scheduling><Marek Vlk><abstracts/vlk.pdf>
<Numeric Planning><Johannes Aldinger><abstracts/aldinger.pdf>
<Exploiting Search Space Structure in Classical Planning: Analyses and Algorithms><Matasaru Asai><abstracts/asai.pdf>
<SAT/SMT techniques for planning problems><Joan Espasa Arxer><abstracts/arxer.pdf>
<Robotic control through model-free reinforcement learning><Ludovic Hofer><abstracts/hofer.pdf>
<Exploiting Symmetries in Sequential Decision Making under Uncertainty><Ankit Anand><abstracts/anand.pdf>
<Recommending and Planning Trip Itineraries for Individual Travellers and Groups of Tourists><Kwan Hui LIM><abstracts/lim.pdf>
<Constructing Plan Trees for Simulated Penetration Testing><Dorin Shmaryahu><abstracts/shmaryahu.pdf>
<Optimization Approaches to Multi-robot Planning and Scheduling><Kyle Booth><abstracts/booth.pdf>
<Learning Static Constraints for Domain Modeling from Training Plans><Rabia Jilani><abstracts/jilani.pdf>
<Using GORE method for Requirement Engineering of Planning \& Scheduling><Javier Martinez><abstracts/martinez.pdf>
<Critical Constrained Planning and an Application to Network Penetration Testing><Marcel Steinmetz><abstracts/steinmetz.pdf>
<Human-Robot Communication in Automated Planning><Aleck MacNally><abstracts/macnally.pdf>"""

mapping = {}
for line in dc.split('\n'):
    title = line.split('<')[1].split('>')[0].replace('\\&', '&amp;')
    link = "proceedings/dc/%s" % line.split('<')[-1].split('>')[0]
    mapping[title] = link
    
#mapping = {line.split('\t')[0].strip(): "http://icaps16.icaps-conference.org/proceedings/planrob16.pdf#page=%s" % line.split('\t')[2].strip() for line in foo.split('\n')}

with open(FILE, 'r') as f:
    html = f.read()

for title in mapping:
    assert title[-1] != '.'
    key = "<span class=\"paper-title\">%s</span>" % title
    rep = "<span class=\"paper-title\"><a href=\"%s\">%s</a></span>" % (mapping[title], title)
    #key = "%s" % title
    #rep = "<a href=\"%s\">%s</a>" % (mapping[title], title)
    assert key in html, "Missing paper: %s" % key
    #assert 'http://' == mapping[title][:7]
    assert ' ' not in mapping[title]
    html = html.replace(key, rep)

#with open(FILE, 'w') as f:
#    f.write(html)

print "Done!"
# Out:
# Done!

# %%
html = """
<p class="left"><a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13001">A Multi-Parameter Complexity Analysis of Cost-Optimal and Net-Benefit Planning</a> / 2<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13001/12655" class="file">PDF</a> --><br />
<i>Meysam Aghighi, Christer Backstrom</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13126">Search Portfolio with Sharing</a> / 11<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13126/12656" class="file">PDF</a> --><br />
<i>Sandip Aine, Maxim Likhachev</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13174">Bound to Plan: Exploiting Classical Heuristics via Automatic Translations of Tail-Recursive HTN Problems</a> / 20<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13174/12657" class="file">PDF</a> --><br />
<i>Ron Alford, Gregor Behnke, Daniel H&ouml;ller, Pascal Bercher, Susanne Biundo, David W. Aha</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13060">OGA-UCT: On-the-Go Abstractions in UCT</a> / 29<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13060/12659" class="file">PDF</a> --><br />
<i>Ankit Anand, Ritesh Noothigattu, Mausam ., Parag Singla</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13099">Change the Plan &mdash; How Hard Can That Be?</a> / 38<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13099/12658" class="file">PDF</a> --><br />
<i>Gregor Behnke, Daniel H&ouml;ller, Pascal Bercher, Susanne Biundo</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13178">Leveraging Probabilistic Reasoning in Deterministic Planning for Large-Scale Autonomous Search-and-Tracking</a> / 47<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13178/12660" class="file">PDF</a> --><br />
<i>Sara Bernardini, Maria Fox, Derek Long, Chiara Piancentini</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12989">A Semantic Notion of Interference for Planning Modulo Theories</a> / 56<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12989/12661" class="file">PDF</a> --><br />
<i>Miquel Bofill, Joan Espasa, Mateu Villaret</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13188">From FOND to Robust Probabilistic Planning: Computing Compact Policies that Bypass Avoidable Deadends</a> / 65<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13188/12662" class="file">PDF</a> --><br />
<i>Alberto Camacho, Christian Muise, Sheila A. McIlraith</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13032">Online Algorithms for the Linear Tape Scheduling Problem</a> / 70<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13032/12663" class="file">PDF</a> --><br />
<i>Carlos Cardonha, Lucas C. Villa Real</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13101">A Compilation of the Full PDDL+ Language into SMT</a> / 79<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13101/12664" class="file">PDF</a> --><br />
<i>Michael Cashmore, Maria Fox, Derek Long, Daniele Magazzeni</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12999">Indefinite-Horizon Reachability in Goal-DEC-POMDPs</a> / 88<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12999/12665" class="file">PDF</a> --><br />
<i>Krishnendu Chatterjee, Martin Chmel&iacute;k</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13187">Have I Been Here Before? State Memoization in Temporal Planning</a> / 97<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13187/12666" class="file">PDF</a> --><br />
<i>Amanda Jane Coles, Andrew Ian Coles</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13091">Practical Undoability Checking via Contingent Planning</a> / 106<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13091/12667" class="file">PDF</a> --><br />
<i>Jeanette Daum, &aacute;lvaro Torralba, J&ouml;rg Hoffmann, Patrik Haslum, Ingo Weber</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13151">Bayesian Optimization with Resource Constraints and Production</a> / 115<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13151/12668" class="file">PDF</a> --><br />
<i>Nima Dolatnia, Alan Fern, Xiaoli Fern</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13181">Robust Partial Order Schedules for RCPSP/max with Durational Uncertainty</a> / 124<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13181/12669" class="file">PDF</a> --><br />
<i>Na Fu, Pradeep Varakantham, Hoong Chuin Lau</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13086">Placement of Loading Stations for Electric Vehicles: Allowing Small Detours</a> / 131<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13086/12670" class="file">PDF</a> --><br />
<i>Stefan Funke, Andre Nusser, Sabine Storandt</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13028">Abstractions for Planning with State-Dependent Action Costs</a> / 140<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13028/12671" class="file">PDF</a> --><br />
<i>Florian Gei&szlig;er, Thomas Keller, Robert Mattm&uuml;ller</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13141">Domain Model Acquisition in Domains with Action Costs</a> / 149<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13141/12672" class="file">PDF</a> --><br />
<i>Peter Gregory, Alan Lindsay</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13123">Assessing the Expressivity of Planning Formalisms through the Comparison to Formal Languages</a> / 158<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13123/12673" class="file">PDF</a> --><br />
<i>Daniel H&ouml;ller, Gregor Behnke, Pascal Bercher, Susanne Biundo</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12994">Multi-Agent Sensor Data Collection with Attrition Risk</a> / 166<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12994/12674" class="file">PDF</a> --><br />
<i>Jeffrey Hudack, Jae C. Oh</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13108">Checking the Dynamic Consistency of Conditional Temporal Networks with Bounded Reaction Times</a> / 175<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13108/12675" class="file">PDF</a> --><br />
<i>Luke Hunsberger, Roberto Posenato</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13081">Automated Creation of Efficient Work Distribution Functions for Parallel Best-First Search</a> / 184<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13081/12676" class="file">PDF</a> --><br />
<i>Yuu Jinnai, Alex Fukunaga</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13090">Hierarchical Linearly-Solvable Markov Decision Problems</a> / 193<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13090/12677" class="file">PDF</a> --><br />
<i>Anders Jonsson, Vicen&ccedil; G&oacute;mez</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13124">Dual Formulations for Optimizing Dec-POMDP Controllers</a> / 202<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13124/12678" class="file">PDF</a> --><br />
<i>Akshat Kumar, Hala Mostafa, Shlomo Zilberstein</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13190">Traps,  Invariants,  and Dead-Ends</a> / 211<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13190/12679" class="file">PDF</a> --><br />
<i>Nir Lipovetzky, Christian Muise, Hector Geffner</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13013">Online Macro Generation for Privacy Preserving Planning</a> / 216<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13013/12680" class="file">PDF</a> --><br />
<i>Shlomi Maliah, Guy Shani, Ronen I. Brafman</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13095">Stronger Privacy Preserving Projections for Multi-Agent Planning</a> / 221<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13095/12681" class="file">PDF</a> --><br />
<i>Shlomi Maliah, Guy Shani, Roni Stern</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13186">Heuristic Guidance for Forward-Chaining Planning with Numeric Uncertainty</a> / 230<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13186/12682" class="file">PDF</a> --><br />
<i>Liana Marinescu, Andrew Ian Coles</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13079">Learning Relational Dynamics of Stochastic Domains for Planning</a> / 235<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13079/12683" class="file">PDF</a> --><br />
<i>David Mart&iacute;nez, Guillem Aleny&agrave;, Carme Torras, Tony Ribeiro, Katsumi Inoue</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13002">The Mathematics of Dispatchability Revisited</a> / 244<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13002/12684" class="file">PDF</a> --><br />
<i>Paul Henry Morris</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13049">Strict Theta*: Shorter Motion Path Planning Using Taut Paths</a> / 253<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13049/12685" class="file">PDF</a> --><br />
<i>Shunhao Oh, Hon Wai Leong</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13093">Efficient Representation of Pattern Databases Using Acyclic Random Hypergraphs</a> / 258<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13093/12686" class="file">PDF</a> --><br />
<i>Mehdi Sadeqi, Howard J. Hamilton</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13138">PARIS: A Polynomial-Time,  Risk-Sensitive Scheduling Algorithm for Probabilistic Simple Temporal Networks with Uncertainty</a> / 267<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13138/12687" class="file">PDF</a> --><br />
<i>Pedro Santana, Tiago Vaquero, Cl&aacute;udio Toledo, Andrew Wang, Cheng Fang, Brian Williams</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13177">Numeric Planning with Disjunctive Global Constraints via SMT</a> / 276<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13177/12688" class="file">PDF</a> --><br />
<i>Enrico Scala, Miquel Ram&iacute;rez, Patrik Haslum, Sylvie Thiebaux</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12990">Generalized Planning with Procedural Domain Control Knowledge</a> / 285<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12990/12689" class="file">PDF</a> --><br />
<i>Javier Segovia Aguas, Sergio Jimenez Celorrio, Anders Jonsson</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13148">An Analysis of Merge Strategies for Merge-and-Shrink Heuristics</a> / 294<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13148/12690" class="file">PDF</a> --><br />
<i>Silvan Sievers, Martin Wehrle, Malte Helmert</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13005">Revisiting Goal Probability Analysis in Probabilistic Planning</a> / 299<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13005/12691" class="file">PDF</a> --><br />
<i>Marcel Steinmetz, Joerg Hoffmann, Olivier Buffet</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13117">Potential Heuristics for Multi-Agent Planning</a> / 308<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13117/12692" class="file">PDF</a> --><br />
<i>Michal &Scaron;tolba, Daniel Fi&scaron;er, Anton&iacute;n Komenda</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13088">Recursive Polynomial Reductions for Classical Planning</a> / 317<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13088/12693" class="file">PDF</a> --><br />
<i>Jan Tozicka, Jan Jakubuv, Martin Svatos, Antonin Komenda</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13179">Heuristic Search in Dual Space for Constrained Stochastic Shortest Path Problems</a> / 326<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13179/12694" class="file">PDF</a> --><br />
<i>Felipe Trevizan, Sylvie Thi&eacute;baux, Pedro Santana, Brian Williams</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13185">A Formal Analysis of Required Cooperation in Multi-Agent Planning</a> / 335<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13185/12695" class="file">PDF</a> --><br />
<i>Yu Zhang, Sarath Sreedharan, Subbarao Kambhampati</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13173">Optimal Scheduling of a Constellation of Earth-Imaging Satellites,  for Maximal Data Throughput and Efficient Human Management</a> / 345<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13173/12696" class="file">PDF</a> --><br />
<i>Sean Augenstein, Alejandra Estanislao, Emmanuel Guere, Sean Blaes</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13050">Planning Curtailment of Renewable Generation in Power Grids</a> / 353<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13050/12697" class="file">PDF</a> --><br />
<i>Sambaran Bandyopadhyay, Pratyush Kumar, Vijay Arya</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13083">A Planning-Based Architecture for a Reconfigurable Manufacturing System</a> / 358<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13083/12698" class="file">PDF</a> --><br />
<i>Stefano Borgo, Amedeo Cesta, Andrea Orlandini, Alessandro Umbrico</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13094">Computing Trace Alignment against Declarative Process Models through Planning</a> / 367<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13094/12699" class="file">PDF</a> --><br />
<i>Giuseppe De Giacomo, Fabrizio Maria Maggi, Andrea Marrella, Sebastian Sardina</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13072">Scheduling Ocean Color Observations for a GEO-Stationary Satellite</a> / 376<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13072/12700" class="file">PDF</a> --><br />
<i>Jeremy Frank, Minh Do, Tony Tran</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13031">Strategic Planning for Setting Up Base Stations in Emergency Medical Systems</a> / 385<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13031/12701" class="file">PDF</a> --><br />
<i>Supriyo Ghosh, Pradeep Varakantham</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13176">Cell Design and Routing of Jobs in a Multisite Make-to-Order Enterprise</a> / 394<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13176/12702" class="file">PDF</a> --><br />
<i>Manoj Gupta, R. P. Jagadeesh Chandra Bose, Partha Dutta</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13087">More Shuttles,  Less Cost: Energy Efficient Planning for Scalable High-Density Warehouse Environments</a> / 403<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13087/12703" class="file">PDF</a> --><br />
<i>Christian H&uuml;tter</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12803">Towards Next Generation Touring: Personalized Group Tours</a> / 412<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12803/12704" class="file">PDF</a> --><br />
<i>Kwan Hui Lim, Jeffrey Chan, Christopher Leckie, Shanika Karunasekera</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12992">Solving Realistic Unit Commitment Problems Using Temporal Planning: Challenges and Solutions</a> / 421<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12992/12705" class="file">PDF</a> --><br />
<i>Chiara Piacentini, Daniele Magazzeni, Derek Long, Maria Fox, Chris Dent</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12991">Planning and Control of Marine Floats in the Presence of Dynamic,  Uncertain Currents</a> / 431<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12991/12706" class="file">PDF</a> --><br />
<i>Martina Troesch, Steve Chien, Yi Chao, John Farrara</i></p>

<h4>Robotics Track</h4>

<p class="left"><a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13189">Integrating Planning and Control for Efficient Path Planning in the Presence of Environmental Disturbances</a> / 441<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13189/12707" class="file">PDF</a> --><br />
<i>Sandip Aine, P. B. Sujit</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13145">Path Planning under Interface-Based Constraints for Assistive Robotics</a> / 450<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13145/12708" class="file">PDF</a> --><br />
<i>Alexander Broad, Brenna Argall</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13065">A Unifying Formalism for Shortest Path Problems with Expensive Edge Evaluations via Lazy Best-First Search over Paths with Edge Selectors</a> / 459<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13065/12709" class="file">PDF</a> --><br />
<i>Christopher M. Dellin, Siddhartha S. Srinivasa</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13105">Real-Time Stochastic Optimal Control for Multi-Agent Quadrotor Systems</a> / 468<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13105/12710" class="file">PDF</a> --><br />
<i>Vicen&ccedil; G&oacute;mez, Sep Thijssen, Andrew Symington, Stephen Hailes, Hilbert J Kappen</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13183">Multi-Agent Path Finding with Kinematic Constraints</a> / 477<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13183/12711" class="file">PDF</a> --><br />
<i>Wolfgang Hoenig, T. K. Satish Kumar, Liron Cohen, Hang Ma, Hong Xu, Nora Ayanian, Sven Koenig</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13120">A Practical Framework for Robust Decision-Theoretic Planning and Execution for Service Robots</a> / 486<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13120/12712" class="file">PDF</a> --><br />
<i>Luca Iocchi, Laurent Jeanpierre, Maria Teresa Lazaro, Abdel-Illah Mouaddib</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12850">Evaluation of Auction-Based Multi-Robot Routing by Parallel Simulation</a> / 495<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/12850/12713" class="file">PDF</a> --><br />
<i>Akihiro Kishimoto, Kiyohito Nagano</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13180">Online Learning of Robot Soccer Free Kick Plans Using a Bandit Approach</a> / 504<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13180/12714" class="file">PDF</a> --><br />
<i>Juan Pablo Mendoza, Reid Simmons, Manuela Veloso</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13175">Experience-Based Robot Task Learning and Planning with Goal Inference</a> / 509<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13175/12715" class="file">PDF</a> --><br />
<i>Vahid Mokhtari, Luis Seabra Lopes, Armando J. Pinho</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13009">Robot Motion Planning for Pouring Liquids</a> / 518<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13009/12716" class="file">PDF</a> --><br />
<i>Zherong Pan, Chonhyon Park, Dinesh Manocha</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13155">Speeding Up A* Search on Visibility Graphs Defined Over Quadtrees to Enable Long Distance Path Planning for Unmanned Surface Vehicles</a> / 527<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13155/12717" class="file">PDF</a> --><br />
<i>Brual C. Shah, Satyandra K. Gupta</i></p>

<p class="left">
<a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13146">Task and Motion Policy Synthesis as Liveness Games</a> / 536<!-- <a href="http://www.aaai.org/ocs/index.php/ICAPS/ICAPS16/paper/view/13146/12718" class="file">PDF</a> --><br />
<i>Yue Wang, Neil T. Dantam, Swarat Chaudhuri, Lydia E. Kavraki</i></p>
"""

html = html.replace('<p class="left">', '').replace('\n\n','\n').replace('\n\n','\n')

lines = filter(lambda x: '<a' == x[:2], html.split('\n'))

mapping = {}
for line in lines:
    url = line.split('<a href=\"')[1].split('\"')[0]
    title = line.split('>')[1].split('</a')[0].replace('  ', ' ').replace('&mdash;','-')
    mapping[title] = url
    
with open('papers.bib', 'r') as f:
    bib = f.read()

for t in mapping:
    assert t in bib, "%s not in bib..." % t
    bib = bib.replace(t, "%s},\n    url      = {%s" % (t,mapping[t]))

#with open('papers.bib', 'w') as f:
#    f.write(bib)
